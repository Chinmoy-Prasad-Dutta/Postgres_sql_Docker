# %%
import pandas as pd

# %%
import time
from time import time

# %%
df = pd.read_csv(
    r"I:\2-Docker_sql_PROJECT\DATA\Absenteeism_at_work.csv", nrows=100)


df
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0     1                  26                 7                3        1
# 1     2                   0                 7                3        1
# 2     3                  23                 7                4        1
# 3     4                   7                 7                5        1
# 4     5                  23                 7                5        1
# ..  ...                 ...               ...              ...      ...
# 95   96                  28                11                3        4
# 96   97                   7                11                4        4
# 97   98                  23                11                5        4
# 98   99                  23                12                3        4
# 99  100                  19                12                3        4
#
#     Transportation expense  Distance from Residence to Work  Service time  \
# 0                      289                               36            13
# 1                      118                               13            18
# 2                      179                               51            18
# 3                      279                                5            14
# 4                      289                               36            13
# ..                     ...                              ...           ...
# 95                     225                               26             9
# 96                     289                               36            13
# 97                     291                               31            12
# 98                     248                               25            14
# 99                     118                               10            10
#
#     Age Work load Average/day   ...  Disciplinary failure  Education  Son  \
# 0    33                239,554  ...                     0          1    2
# 1    50                239,554  ...                     1          1    1
# 2    38                239,554  ...                     0          1    0
# 3    39                239,554  ...                     0          1    2
# 4    33                239,554  ...                     0          1    2
# ..  ...                    ...  ...                   ...        ...  ...
# 95   28                306,345  ...                     0          1    1
# 96   33                306,345  ...                     0          1    2
# 97   40                306,345  ...                     0          1    1
# 98   47                261,306  ...                     0          1    2
# 99   37                261,306  ...                     0          1    0
#
#     Social drinker  Social smoker  Pet  Weight  Height  Body mass index  \
# 0                1              0    1      90     172               30
# 1                1              0    0      98     178               31
# 2                1              0    0      89     170               31
# 3                1              1    0      68     168               24
# 4                1              0    1      90     172               30
# ..             ...            ...  ...     ...     ...              ...
# 95               0              0    2      69     169               24
# 96               1              0    1      90     172               30
# 97               1              0    1      73     171               25
# 98               0              0    1      86     165               32
# 99               0              0    0      83     172               28
#
#     Absenteeism time in hours
# 0                           4
# 1                           0
# 2                           2
# 3                           4
# 4                           2
# ..                        ...
# 95                          3
# 96                         24
# 97                          3
# 98                          1
# 99                         64
#
# [100 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ID                               100 non-null    int64
#  1   Reason for absence               100 non-null    int64
#  2   Month of absence                 100 non-null    int64
#  3   Day of the week                  100 non-null    int64
#  4   Seasons                          100 non-null    int64
#  5   Transportation expense           100 non-null    int64
#  6   Distance from Residence to Work  100 non-null    int64
#  7   Service time                     100 non-null    int64
#  8   Age                              100 non-null    int64
#  9   Work load Average/day            100 non-null    object
#  10  Hit target                       100 non-null    int64
#  11  Disciplinary failure             100 non-null    int64
#  12  Education                        100 non-null    int64
#  13  Son                              100 non-null    int64
#  14  Social drinker                   100 non-null    int64
#  15  Social smoker                    100 non-null    int64
#  16  Pet                              100 non-null    int64
#  17  Weight                           100 non-null    int64
#  18  Height                           100 non-null    int64
#  19  Body mass index                  100 non-null    int64
#  20  Absenteeism time in hours        100 non-null    int64
# dtypes: int64(20), object(1)
# memory usage: 16.5+ KB

# %%
print(pd.io.sql.get_schema(df, name="Absenteeism_at_work"))
# Out:
# CREATE TABLE "Absenteeism_at_work" (
# "ID" INTEGER,
#   "Reason for absence" INTEGER,
#   "Month of absence" INTEGER,
#   "Day of the week" INTEGER,
#   "Seasons" INTEGER,
#   "Transportation expense" INTEGER,
#   "Distance from Residence to Work" INTEGER,
#   "Service time" INTEGER,
#   "Age" INTEGER,
#   "Work load Average/day " TEXT,
#   "Hit target" INTEGER,
#   "Disciplinary failure" INTEGER,
#   "Education" INTEGER,
#   "Son" INTEGER,
#   "Social drinker" INTEGER,
#   "Social smoker" INTEGER,
#   "Pet" INTEGER,
#   "Weight" INTEGER,
#   "Height" INTEGER,
#   "Body mass index" INTEGER,
#   "Absenteeism time in hours" INTEGER
# )

# %%
import os


def get_schema_for_project(folder_path):
    """Loops through all CSV files in a folder.

    Args:
        folder_path: Path to the folder containing the files.
    """
    for filename in os.listdir(folder_path):
        if filename.endswith(".csv"):
            print(f"Processing CSV file: {filename}")

            print(pd.io.sql.get_schema(df, name=f"{filename}"))

            print("--------------")


# Example usage:
folder_path = r"I:\2-Docker_sql_PROJECT\DATA"
get_schema_for_project(folder_path)
# Out:
# Processing CSV file: Absenteeism_at_work.csv
# CREATE TABLE "Absenteeism_at_work.csv" (
# "ID" INTEGER,
#   "Reason for absence" INTEGER,
#   "Month of absence" INTEGER,
#   "Day of the week" INTEGER,
#   "Seasons" INTEGER,
#   "Transportation expense" INTEGER,
#   "Distance from Residence to Work" INTEGER,
#   "Service time" INTEGER,
#   "Age" INTEGER,
#   "Work load Average/day " TEXT,
#   "Hit target" INTEGER,
#   "Disciplinary failure" INTEGER,
#   "Education" INTEGER,
#   "Son" INTEGER,
#   "Social drinker" INTEGER,
#   "Social smoker" INTEGER,
#   "Pet" INTEGER,
#   "Weight" INTEGER,
#   "Height" INTEGER,
#   "Body mass index" INTEGER,
#   "Absenteeism time in hours" INTEGER
# )
# --------------
# Processing CSV file: compensation.csv
# CREATE TABLE "compensation.csv" (
# "ID" INTEGER,
#   "Reason for absence" INTEGER,
#   "Month of absence" INTEGER,
#   "Day of the week" INTEGER,
#   "Seasons" INTEGER,
#   "Transportation expense" INTEGER,
#   "Distance from Residence to Work" INTEGER,
#   "Service time" INTEGER,
#   "Age" INTEGER,
#   "Work load Average/day " TEXT,
#   "Hit target" INTEGER,
#   "Disciplinary failure" INTEGER,
#   "Education" INTEGER,
#   "Son" INTEGER,
#   "Social drinker" INTEGER,
#   "Social smoker" INTEGER,
#   "Pet" INTEGER,
#   "Weight" INTEGER,
#   "Height" INTEGER,
#   "Body mass index" INTEGER,
#   "Absenteeism time in hours" INTEGER
# )
# --------------
# Processing CSV file: Reasons.csv
# CREATE TABLE "Reasons.csv" (
# "ID" INTEGER,
#   "Reason for absence" INTEGER,
#   "Month of absence" INTEGER,
#   "Day of the week" INTEGER,
#   "Seasons" INTEGER,
#   "Transportation expense" INTEGER,
#   "Distance from Residence to Work" INTEGER,
#   "Service time" INTEGER,
#   "Age" INTEGER,
#   "Work load Average/day " TEXT,
#   "Hit target" INTEGER,
#   "Disciplinary failure" INTEGER,
#   "Education" INTEGER,
#   "Son" INTEGER,
#   "Social drinker" INTEGER,
#   "Social smoker" INTEGER,
#   "Pet" INTEGER,
#   "Weight" INTEGER,
#   "Height" INTEGER,
#   "Body mass index" INTEGER,
#   "Absenteeism time in hours" INTEGER
# )
# --------------

# %%
from sqlalchemy import create_engine as ce

# %%
# engine = ce("postgresql://root:root@localhost:5432/project")

# %%
# engine.connect()

# %%
# print(pd.io.sql.get_schema(df, name="Absenteeism_at_work", con=engine))

# %%
def apply_schema(folder_path, engine):
    """Loops through all CSV files in a folder and attempts to print their schema to the console.

    Args:
        folder_path: Path to the folder containing the CSV files.
        engine: A SQLAlchemy engine object for database connection (if applicable).
    """
    for filename in os.listdir(folder_path):
        if filename.endswith(".csv"):
            print(f"Processing CSV file: {filename}")

            # Read the CSV data into a DataFrame (assuming no schema is provided)
            try:
                df = pd.read_csv(os.path.join(folder_path, filename))
                if engine is not None:
                    # If engine is provided, attempt to print schema using SQLAlchemy
                    print(pd.io.sql.get_schema(
                        df, name=f"{filename}", con=engine))
                else:
                    # If no engine, print basic column information
                    print(df.dtypes)  # Print data types of each column
            except FileNotFoundError:
                print(f"Error: File not found - {filename}")

            print("--------------")


# Example usage (assuming you have a database connection established in engine)
folder_path = r"I:\2-Docker_sql_PROJECT\DATA"
engine = ce("postgresql://root:root@localhost:5432/project")
apply_schema(folder_path, engine)
# Out:
# Processing CSV file: Absenteeism_at_work.csv
#
# CREATE TABLE "Absenteeism_at_work.csv" (
# 	"ID" BIGINT,
# 	"Reason for absence" BIGINT,
# 	"Month of absence" BIGINT,
# 	"Day of the week" BIGINT,
# 	"Seasons" BIGINT,
# 	"Transportation expense" BIGINT,
# 	"Distance from Residence to Work" BIGINT,
# 	"Service time" BIGINT,
# 	"Age" BIGINT,
# 	"Work load Average/day " TEXT,
# 	"Hit target" BIGINT,
# 	"Disciplinary failure" BIGINT,
# 	"Education" BIGINT,
# 	"Son" BIGINT,
# 	"Social drinker" BIGINT,
# 	"Social smoker" BIGINT,
# 	"Pet" BIGINT,
# 	"Weight" BIGINT,
# 	"Height" BIGINT,
# 	"Body mass index" BIGINT,
# 	"Absenteeism time in hours" BIGINT
# )
#
#
# --------------
# Processing CSV file: compensation.csv
#
# CREATE TABLE "compensation.csv" (
# 	"ID" BIGINT,
# 	"comp/hr" BIGINT
# )
#
#
# --------------
# Processing CSV file: Reasons.csv
#
# CREATE TABLE "Reasons.csv" (
# 	"Number" BIGINT,
# 	"Reason" TEXT
# )
#
#
# --------------

# %%
df_iter = pd.read_csv(
    r"I:\2-Docker_sql_PROJECT\DATA\Absenteeism_at_work.csv",
    iterator=True,
    chunksize=100000,
)

# %%
def load_db_to_project(folder_path, engine):
    """Loops through all CSV files in a folder and attempts to print their schema to the console.

    Args:
        folder_path: Path to the folder containing the CSV files.
        engine: A SQLAlchemy engine object for database connection (if applicable).
    """
    for filename in os.listdir(folder_path):
        if filename.endswith(".csv"):
            print(f"Processing CSV file: {filename}")

            # Read the CSV data into a DataFrame (assuming no schema is provided)
            try:
                df = pd.read_csv(os.path.join(folder_path, filename))
                if engine is not None:
                    # If engine is provided, attempt to print schema using SQLAlchemy
                    print(pd.io.sql.get_schema(df, name=f"{filename}", con=engine))
                else:
                    # If no engine, print basic column information
                    print(df.dtypes)  # Print data types of each column
            except FileNotFoundError:
                print(f"Error: File not found - {filename}")

            df_iter = pd.read_csv(
                os.path.join(folder_path, filename),
                iterator=True,
                chunksize=100000,
            )

            count = 0
            while True:
                try:
                    df = next(df_iter)
                    table_name = filename[:-4]
                    df.to_sql(name=table_name, con=engine, if_exists="append")
                    count += 1
                    print(f"{count}")
                    print("--------------")
                except StopIteration:
                    # Handle the end of the iterator here
                    print("Reached the end of the iterator. Stopping...")
                    break  # Exit the loop


# Example usage (assuming you have a database connection established in engine)
folder_path = r"I:\2-Docker_sql_PROJECT\DATA"
engine = ce("postgresql://root:root@localhost:5432/project")
load_db_to_project(folder_path, engine)
# Out:
# Processing CSV file: Absenteeism_at_work.csv
#
# CREATE TABLE "Absenteeism_at_work.csv" (
# 	"ID" BIGINT,
# 	"Reason for absence" BIGINT,
# 	"Month of absence" BIGINT,
# 	"Day of the week" BIGINT,
# 	"Seasons" BIGINT,
# 	"Transportation expense" BIGINT,
# 	"Distance from Residence to Work" BIGINT,
# 	"Service time" BIGINT,
# 	"Age" BIGINT,
# 	"Work load Average/day " TEXT,
# 	"Hit target" BIGINT,
# 	"Disciplinary failure" BIGINT,
# 	"Education" BIGINT,
# 	"Son" BIGINT,
# 	"Social drinker" BIGINT,
# 	"Social smoker" BIGINT,
# 	"Pet" BIGINT,
# 	"Weight" BIGINT,
# 	"Height" BIGINT,
# 	"Body mass index" BIGINT,
# 	"Absenteeism time in hours" BIGINT
# )
#
#
# 1
# --------------
# Reached the end of the iterator. Stopping...
# Processing CSV file: compensation.csv
#
# CREATE TABLE "compensation.csv" (
# 	"ID" BIGINT,
# 	"comp/hr" BIGINT
# )
#
#
# 1
# --------------
# Reached the end of the iterator. Stopping...
# Processing CSV file: Reasons.csv
#
# CREATE TABLE "Reasons.csv" (
# 	"Number" BIGINT,
# 	"Reason" TEXT
# )
#
#
# 1
# --------------
# Reached the end of the iterator. Stopping...

# %%
# df = next(df_iter)
# len(df)

# %%
# df.head(n=0).to_sql(name="Absenteeism_at_work", con=engine, if_exists="replace")

# %%
# %time
# df.to_sql(name='Absenteeism_at_work', con = engine, if_exists='append')

# %%
# count = 0
# while True:
#     t_start = time()
#     df = next(df_iter)

#     df.to_sql(name="Absenteeism_at_work", con=engine, if_exists="append")
#     count += 1

#     t_end = time()

#     print(f"inserted {count}th iteration...took {(t_end-t_start):.2f} seconds")
